# %%
import pandas as pd

# %% [markdown]
# # import file (Kesehatan)

# %% [markdown]
# #### .csv

# %%
df = pd.read_csv(r'D:\QUIZ ALGORITMA\quiz 13\Student Mental health.csv')
print(df)
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %% [markdown]
# #### .xlsx

# %%
df = pd.read_excel(r'D:\QUIZ ALGORITMA\quiz 13\Mental health Depression disorder Data.xlsx')
print(df)
# Out:
#            Entity Code  Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990           0.160560              0.697779
# 1     Afghanistan  AFG  1991           0.160312              0.697961
# 2     Afghanistan  AFG  1992           0.160135              0.698107
# 3     Afghanistan  AFG  1993           0.160037              0.698257
# 4     Afghanistan  AFG  1994           0.160022              0.698469
# ...           ...  ...   ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %% [markdown]
# # import file (Keuangan)

# %% [markdown]
# #### .csv

# %%
df = pd.read_csv(r'D:\QUIZ ALGORITMA\quiz 13\Finance_data.csv')
print(df)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df = pd.read_excel(r'D:\QUIZ ALGORITMA\quiz 13\Financial Sample.xlsx')
print(df)
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                   Germany  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %% [markdown]
# # import file (Lainnya)
# (kpop)

# %% [markdown]
# #### .csv

# %%
df = pd.read_csv(r'D:\QUIZ ALGORITMA\quiz 13\kpop idols.csv')
print(df)
# Out:
#      Stage Name Stage Name Full Name Full Name Korean Name Korean Name  \
# 0                  Taeyeon         Kim Taeyeon                     김태연
# 1                    Sunny          Lee Sunkyu                     이순규
# 2                  Tiffany       Hwang Miyoung                     황미영
# 3                  Hyoyeon         Kim Hyoyeon                     김효연
# 4                     Yuri           Kwon Yuri                     권유리
# ...                    ...                 ...                     ...
# 1661                 Minji           Kim Minji                     김민지
# 1662                 Hanni       Pham Ngoc Han                    팜응옥헌
# 1663              Danielle            Mo Jihye                     모지혜
# 1664                Haerin         Kang Haerin                     강해린
# 1665                 Hyein           Lee Hyein                     이혜인
#
#      K. Stage Name K. Stage Name Date of Birth Date of Birth Group Group  \
# ...

# %% [markdown]
# #### .xlsx

# %%
df = pd.read_excel(r'D:\QUIZ ALGORITMA\quiz 13\kpop_girl_group_company_active.xlsx')
print(df)
# Out:
#             X:IN 2023-04-11 00:00:00          Escrow        Yes
# 0       PRIMROSE          2023-03-13              AO        Yes
# 1      LIMELIGHT          2023-02-17             143        Yes
# 2        tripleS          2023-02-13         MODHAUS        Yes
# 3    FIFTY FIFTY          2022-11-18         ATTRAKT        Yes
# 4        ARTBEAT          2022-11-16     AB Creative        Yes
# ..           ...                 ...             ...        ...
# 210      Jewelry          2001-03-30     Star Empire         No
# 211        S.E.S          1997-11-01              SM         No
# 212   Baby V.O.X          1997-07-05        DR Music         No
# 213         ADYA                 NaT  Starting House        Yes
# 214  BABYMONSTER                 NaT              YG  Pre-Debut
#
# [215 rows x 4 columns]
